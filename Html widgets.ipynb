# %%
from IPython.display import Audio, Image, YouTubeVideo, HTML

# %%
img_path = 'https://lightsinthedark.files.wordpress.com/2017/11/iss-from-endeavour-sts127-7-28-09-2.jpg'
Image(img_path)

# %%
id = 'DjpCHNYQodY'
YouTubeVideo(id = id, width = 500, height = 400)
